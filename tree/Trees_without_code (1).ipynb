# %% [markdown]
# <center><h1>TREES</h1></center>
#
# Trees are well-known as a non-linear data structure. They don’t store data in a linear way. They organize data hierarchically.
#
# A tree is non-linear and a hierarchical data structure consisting of a collection of nodes such that each node of the tree stores a value and a list of references to other nodes (the “children”).
#
# <b>Terminology summary</b>
# - Root is the topmost node of the tree
# - Edge is the link between two nodes
# - Child is a node that has a parent node
# - Parent is a node that has an edge to a child node
# - Leaf is a node that does not have a child node in the tree
# - Height is the length of the longest path to a leaf
# - Depth is the length of the path to its root
#
# <img src="https://media.geeksforgeeks.org/wp-content/cdn-uploads/20201129105858/Tree-Basic-Terminology.png" />
#
# ### Types of Tree data structures
#
# 1. <b>General tree:</b>
# A general tree data structure has no restriction on the number of nodes. It means that a parent node can have any number of child nodes.
#
# 2. <b>Binary tree:</b>
# A node of a binary tree can have a maximum of two child nodes. In the given tree diagram, node B, D, and F are left children, while E, C, and G are the right children.
#
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20211127152300/imi-300x258.png" />
#
#     - Full Binary tree
#     - Complete Binary tree
#     - Perfect Binary tree
#     - Balanced Binary tree
#     - Degenerate Binary tree
#
# 3. <b>Balanced tree:</b>
# If the height of the left sub-tree and the right sub-tree is equal or differs at most by 1, the tree is known as a balanced tree.
#
# 4. <b>Binary search tree:</b>
# As the name implies, binary search trees are used for various searching and sorting algorithms. The examples include AVL tree and red-black tree. It is a non-linear data structure. It shows that the value of the left node is less than its parent, while the value of the right node is greater than its parent.
#
# <b>Some more properties are:<b>
#
# - Traversing in a tree is done by depth first search and breadth first search algorithm.
# - It has no loop and no circuit
# - It has no self-loop
# - Its hierarchical model.

# %% [markdown]
# ## **`WATCH ALL VIDEOS IN THE PORTAL`**

# %% [markdown]
# ### **`Watch Video 1: Trees Introduction`**

# %%
class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

# %% [markdown]
# ## Tree Traversals
#
# <img src="https://media.geeksforgeeks.org/wp-content/cdn-uploads/2009/06/tree12.gif" width="500px" />

# %% [markdown]
# ### Inorder Traversal
#
# Algorithm Inorder (tree)
#
# ```
#    1. Traverse the left subtree, i.e., call Inorder(left-subtree)
#    2. Visit the root.
#    3. Traverse the right subtree, i.e., call Inorder(right-subtree)
# ```

# %% [markdown]
# ### **`Watch Video 2: Inorder Traversal`**

# %%
def inorder_traversal(root):
  if root==None:
    return
  preorder_traversal(root.left)
  print(root.val,end=' ')
  preorder_traversal(root.right)

# %% [markdown]
# ### Preorder Traversal
#
# Algorithm Preorder (tree)
# ```
#    1. Visit the root.
#    2. Traverse the left subtree, i.e., call Preorder(left-subtree)
#    3. Traverse the right subtree, i.e., call Preorder(right-subtree)
# ```

# %% [markdown]
# ### **`Watch Video 3: Preorder Traversal`**

# %%
def preorder_traversal(root):
  if root==None:
    return
  print(root.val,end=' ')
  preorder_traversal(root.left)
  preorder_traversal(root.right)

# %% [markdown]
# ### Postorder Traversal
#
# Algorithm Postorder (tree)
# ```
#    1. Traverse the left subtree, i.e., call Postorder(left-subtree)
#    2. Traverse the right subtree, i.e., call Postorder(right-subtree)
#    3. Visit the root.
# ```

# %% [markdown]
# ### **`Watch Video 4: Postorder Traversal`**

# %%
def postorder_traversal(root):
  if root==None:
    return
  preorder_traversal(root.left)
  preorder_traversal(root.right)
  print(root.val,end=' ')

# %% [markdown]
# ### Level Order Traversal
#
# Algorithm LevelOrder (tree)
#
# ```
# 1) Create an empty queue q
# 2) temp_node = root
# 3) Loop while temp_node is not NULL
#     a) print temp_node->val
#     b) Enqueue temp_node’s children
#       (first left then right children) to q
#     c) Dequeue a node from q.
# ```

# %% [markdown]
# ### **`Watch Video 5: Level Order Traversal`**

# %%
def level_order_traversal(root):
  qu=[]
  qu.append(root)
  while(len(qu)!=0):
    r=qu.pop(0)
    print(r.val,end=' ')
    if r.left!=None:
      qu.append(r.left)
    if r.right!=None:
      qu.append(r.right)

# %%
# Driver code
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

print("Preorder traversal of binary tree is")
preorder_traversal(root)
print("\nInorder traversal of binary tree is")
inorder_traversal(root)
print("\nPostorder traversal of binary tree is")
postorder_traversal(root)
print("\nLevel Order traversal of binary tree is")
level_order_traversal(root)
# Out:
# Preorder traversal of binary tree is
# 1 2 4 5 3
# Inorder traversal of binary tree is
# 2 4 5 1 3
# Postorder traversal of binary tree is
# 2 4 5 3 1
# Level Order traversal of binary tree is
# 1 2 3 4 5

# %% [markdown]
# ## Problems

# %% [markdown]
# ### Problem 1
#
# Given the root of a binary tree, return its maximum depth.
#
# A binary tree's maximum depth is the number of nodes along the longest path from the root node down to the farthest leaf node.
#
# <img src="https://assets.leetcode.com/uploads/2020/11/26/tmp-tree.jpg" />

# %% [markdown]
# ### **`Watch Video 6: Max Depth problem`**

# %%
def maxDepth(root):
  if root is None:
    return 0

  a=maxDepth(root.left)
  b=maxDepth(root.right)
  return max(a,b)+1

# %%
# driver code
root = Node(3)
root.left = Node(9)
root.right = Node(20)
root.right.left = Node(15)
root.right.right = Node(7)

maxDepth(root)
# Out:
# 3

# %% [markdown]
# ### Problem 2
#
# Find the Diameter of a Binary Tree. Diameter is the length of the longest path between any 2 nodes in the tree and this path may or may not pass from the root.

# %% [markdown]
# ### **`Watch Video 7: Diameter Problem`**

# %%
def findDiameter(root,m):
  if root==None:
    return
  left=maxDepth(root.left)
  right=maxDepth(root.right)
  m.append(left+right+1)
  findDiameter(root.left,m)
  findDiameter(root.right,m)
  return max(m)

# %%
# driver code
root = Node(3)
root.left = Node(9)
root.right = Node(20)

root.right.left = Node(15)
root.right.right = Node(7)
p=[]
findDiameter(root,p)
# Out:
# 4

# %%
# driver code
root = Node(3)
root.left = Node(9)
root.left.left = Node(15)
root.left.right = Node(7)
root.left.right.right = Node(20)
root.left.left.left = Node(10)
p=[]
findDiameter(root,p)
# Out:
# 5

# %% [markdown]
# ### Problem 3
#
# Given two Binary Tree. Write a program to check if two trees are identical or not.

# %% [markdown]
# ### **`Watch Video 8: Identical Problem`**

# %%
def level_order_traversal(root):
  qu=[]
  result=[]
  qu.append(root)
  while(len(qu)!=0):
    r=qu.pop(0)
    result.append(r.val)
    if r.left!=None:
      qu.append(r.left)
    if r.right!=None:
      qu.append(r.right)
  return result
def checkForIdentical(root1, root2):
  r1=level_order_traversal(root1)
  r2=level_order_traversal(root2)
  if r1==r2:
    return True
  else:
    return False

# %%
# driver code

# creating tree 1
root1 = Node(1)
root1.left = Node(2)
root1.right = Node(3)
root1.right.left = Node(4)
root1.right.right = Node(5)

# creating tree 2
root2 = Node(1)
root2.left = Node(2)
root2.right = Node(3)
root2.right.left = Node(4)
root2.right.right = Node(5)

checkForIdentical(root1, root2)
# Out:
# True

# %%
# driver code

# creating tree 1
root1 = Node(1)
root1.left = Node(2)
root1.right = Node(3)
root1.right.left = Node(4)
root1.right.right = Node(5)

# creating tree 2
root2 = Node(1)
root2.left = Node(2)
root2.right = Node(3)
root2.right.left = Node(4)

checkForIdentical(root1, root2)
# Out:
# False

# %% [markdown]
# ### Problem 4
#
# Given a Binary Tree, find the Left view of it. The Left view of a Binary Tree is a set of nodes visible when the tree is viewed from the left side.

# %% [markdown]
# ### **`Watch Video 9: Left View Problem`**

# %%
def getLeftView(root):

    ans = {}

    def dfs(node, level, pos):

        if node is None:
            return

        # first node at level OR more left than previous
        if level not in ans or pos < ans[level][0]:
            ans[level] = (pos, node.val)

        dfs(node.left, level + 1, pos - 1)

        dfs(node.right, level + 1, pos + 1)

    dfs(root, 0, 0)

    for level in sorted(ans):
        print(ans[level][1], end=" ")

# %%
# driver code
# creating tree
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.right.left = Node(4)
root.right.right = Node(5)

getLeftView(root)
# Out:
# 1 2 4

# %%
# driver code

# creating tree
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.right.left = Node(4)
root.right.right = Node(5)
root.right.left.left = Node(8)

getLeftView(root)
# Out:
# 1 2 4 8

# %% [markdown]
# ### Problem 5
#
# Given a binary tree, Find the Lowest Common Ancestor for two given Nodes (x,y).
#
# <b>Lowest Common Ancestor(LCA):</b> The lowest common ancestor is defined between two nodes x and y as the lowest node in T that has both x and y as descendants (where we allow a node to be a descendant of itself.

# %% [markdown]
# ### **`Watch Video 10: Lowest Common Ancestor Problem`**

# %%
def lowestCommonAncestor(root, p, q):

    # return root if root is None or root itself is p/q
    if root is None or root.val == p.val or root.val == q.val:
        return root

    # search left and right subtree
    left = lowestCommonAncestor(root.left,p,q)

    right = lowestCommonAncestor(root.right,p,q)

    # only right side found something
    if left is None:
        return right

    # only left side found something
    if right is None:
        return left

    # both sides found nodes -> split happened here
    return root

# %%
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
p = Node(6)
root.right.left = p
q = Node(7)
root.right.right = q


lowestCommonAncestor(root, p, q).val
# Out:
# 3

# %%
root = Node(1)
root.left = Node(2)
root.right = Node(3)
p = Node(4)
root.left.left = p
q = Node(5)
root.left.right = q
root.right.left = Node(6)
root.right.right = Node(7)


lowestCommonAncestor(root, p, q).val
# Out:
# 2

# %% [markdown]
# ## Practice Problems

# %% [markdown]
# ### Practice Problem 1
#
# Check whether the given Binary Tree is a Balanced Binary Tree or not. A binary tree is balanced if, for all nodes in the tree, the difference between left and right subtree height is not more than 1.

# %%
def dfsTree(root,b):
    if root==None:
      return b
    else:
      ans=maxDepth(root.left)-maxDepth(root.right)
      if ans<0:
        ans=ans*-1
      if ans >1:
        b=False
        return b
      else:



        a1=dfsTree(root.left,b)
        a2=dfsTree(root.right,a1)
        return a2


def isBalanced(root):
  b=True
  return dfsTree(root,b)

# %%
# driver code
root = Node(4)
root.left = Node(7)
root.right = Node(8)
root.right.left = Node(1)
root.right.right = Node(0)
root.right.left.left = Node(3)
root.right.left.right = Node(3)

isBalanced(root)
# Out:
# False

# %%
root = Node(1)

# Left subtree (unbalanced internally)
root.left = Node(2)

root.left.left = Node(3)
root.left.left.left = Node(4)
root.left.left.left.left = Node(5)

root.left.right = Node(6)

# Right subtree added to keep root balanced
root.right = Node(7)

root.right.left = Node(8)
root.right.right = Node(9)

root.right.left.left = Node(10)
root.right.left.right = Node(11)

root.right.right.left = Node(12)
root.right.right.right = Node(13)

print(isBalanced(root))
# Out:
# False

# %%
root = Node(1)

root.left = Node(2)
root.right = Node(5)

root.left.left = Node(3)

root.left.left.left = Node(4)

print(isBalanced(root))
# Out:
# False

# %%
# driver code
root = Node(4)
root.left = Node(7)
root.right = Node(8)
root.right.left = Node(1)
root.right.right = Node(0)

isBalanced(root)
# Out:
# True

# %% [markdown]
# ### Practice Problem 2
#
# Write a program to find the maximum sum path in a binary tree. A path in a binary tree is a sequence of nodes where every adjacent pair of nodes are connected by an edge. A node can only appear in the sequence at most once. A path need not pass from the root. We need to find the path with the maximum sum in the binary tree.

# %%
def maxPathSum(root,mx=[]):
    if root==None:
      return 0,0
    a,mxx1=maxPathSum(root.left)
    b,mxx2=maxPathSum(root.right)
    k=(root.val)+max(a,b)
    mx.append(max(a+b+root.val,k))
    return k,max(mx)

# %%
root = Node(-10)
root.left = Node(9)
root.right = Node(20)
root.right.left = Node(15)
root.right.right = Node(7)
(maxPathSum(root)[1])
# Out:
# 42

# %%
a=[1,2,0]
max(a)
# Out:
# 2

# %%
root = Node(15)
root.left = Node(10)
root.right = Node(20)
root.right.left = Node(-30)
root.right.right = Node(-15)

maxPathSum(root)[1]
# Out:
# 42

# %% [markdown]
# ### Practice Problem 3
#
# Print the right view of binary tree.

# %%
def getRightView(root, ans, level=0):

    if root is None:
        return ans

    if level == len(ans):
        ans.append(root.val)

    getRightView(root.right, ans, level + 1)

    getRightView(root.left, ans, level + 1)

    return ans


# driver code

root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.right.left = Node(4)
root.right.right = Node(5)

answer = getRightView(root, ans=[])

print(answer)
# Out:
# [1, 3, 5]

# %%
# driver code

# creating tree
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.right.left = Node(4)
root.right.right = Node(5)
root.right.left.left = Node(8)

answer=(getRightView(root,ans=[]))
answer.insert(0,root.val)
print(answer)
# Out:
# [1, 1, 3, 5, 8]

# %% [markdown]
# ### Practice Problem 4
#
# Search for a given key in a binary search tree.

# %%
from re import search
def searchKey(root, key,l):
    if root==None:
      return l
    searchKey(root.left,key,l)
    if root.val==key:
      l[0]+=1
      return l
    searchKey(root.right,key,l)
    return l

# %%
# driver code

# creating tree
root = Node(8)
root.left = Node(3)
root.right = Node(10)
root.left.left = Node(1)
root.left.right = Node(6)
root.right.right = Node(14)
l=[0]
if (searchKey(root, 6,l))[0]==1:
  print(True)
else:
  print(False)
# Out:
# True

# %%
# driver code

# creating tree
root = Node(8)
root.left = Node(3)
root.right = Node(10)
root.left.left = Node(1)
root.left.right = Node(6)
root.right.right = Node(14)
l=[0]
if (searchKey(root, 12,l))[0]==1:
  print(True)
else:
  print(False)
# Out:
# False

# %% [markdown]
# <center><h1>Thank You</h1></center>
